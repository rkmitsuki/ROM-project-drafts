# %%
import matplotlib.pyplot as plt
import numpy as np

f = 1.8
a = 0.6
s = 0.3
b = round(1.8/s)
print(b)
x = np.linspace(a, f, 1024)
y = np.linspace(a, b, 1024)

print(x)
print(y)

X,Y = np.meshgrid(x,y)

print(X)
print(Y)
k = np.cos(X)

#fig, ax = plt.subplots()
#im = ax.imshow(data2d)

#fig.colorbar(im, ax=ax)

plt.contourf(x,y,k, cmap='turbo')
# Out:
# 6
# [0.6        0.60117302 0.60234604 ... 1.79765396 1.79882698 1.8       ]
# [0.6        0.60527859 0.61055718 ... 5.98944282 5.99472141 6.        ]
# [[0.6        0.60117302 0.60234604 ... 1.79765396 1.79882698 1.8       ]
#  [0.6        0.60117302 0.60234604 ... 1.79765396 1.79882698 1.8       ]
#  [0.6        0.60117302 0.60234604 ... 1.79765396 1.79882698 1.8       ]
#  ...
#  [0.6        0.60117302 0.60234604 ... 1.79765396 1.79882698 1.8       ]
#  [0.6        0.60117302 0.60234604 ... 1.79765396 1.79882698 1.8       ]
#  [0.6        0.60117302 0.60234604 ... 1.79765396 1.79882698 1.8       ]]
# [[0.6        0.6        0.6        ... 0.6        0.6        0.6       ]
#  [0.60527859 0.60527859 0.60527859 ... 0.60527859 0.60527859 0.60527859]
#  [0.61055718 0.61055718 0.61055718 ... 0.61055718 0.61055718 0.61055718]
#  ...
#  [5.98944282 5.98944282 5.98944282 ... 5.98944282 5.98944282 5.98944282]
#  [5.99472141 5.99472141 5.99472141 ... 5.99472141 5.99472141 5.99472141]
# ...

# %%
#test
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors

t = np.linspace(0.6, 1.8, 10024)
data2d = np.sin(t)[:, np.newaxis] * np.cos(t)[np.newaxis, :]

fig, ax = plt.subplots()
custom_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","deepskyblue","dodgerblue","lightskyblue","aqua","cyan","lightgreen","mediumaquamarine","palegreen","lawngreen","yellow","gold","darkorange","coral","sienna"])
im = ax.imshow(data2d, cmap=custom_cmap)

ax, _ = mpl.colorbar.make_axes(plt.gca())
cbar = mpl.colorbar.ColorbarBase(ax, cmap=custom_cmap4,
                       norm=mpl.colors.Normalize(vmin=0, vmax=2.2))


plt.show()

# %%
#test
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors

t = np.linspace(0.6, 1.8, 10024)
data2d = np.sin(t)[:, np.newaxis] * np.cos(t)[np.newaxis, :]

fig, ax = plt.subplots()
custom_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["yellow","palegreen","aqua"])
im = ax.imshow(data2d, cmap=custom_cmap)

fig.colorbar(im, ax=ax)


plt.show()

# %%
#test
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.patches import Rectangle
from matplotlib.patches import Polygon
import matplotlib.transforms as mtransforms
import matplotlib.colors
import matplotlib.patches as patches
from matplotlib.path import Path
import matplotlib as mpl

def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)


c1='blue' #blue
c2='aqua' #green
n=500

fig, ax = plt.subplots(figsize=(8, 5))
for x in range(n+1):
    custom_cmap = ax.axvline(x,color=colorFader(c1,c2,x/n), linewidth=4)

# %%
#test
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.patches import Rectangle
from matplotlib.patches import Polygon
import matplotlib.transforms as mtransforms
import matplotlib.colors
import matplotlib.patches as patches
from matplotlib.path import Path
import matplotlib as mpl


#Axis view:

fig, ax = plt.subplots()
ax.axis([0, 85, 10, 50])

# range of x is 6.8 to 12.8 
# range of y is 41.22 to 81.22 
# range of z is 12 to 24

x=10
y=72
z=20









if x>9.8:
    h="deepskyblue"
    j="deepskyblue"
    d="springgreen"
elif x<7.5:
    h="blue"
    j="blue"
    d="yellow"
else:
    h="blue"
    j="deepskyblue"
    d="springgreen"



x=(((x-6.8)/6)*2)-1 
y=(((y-41.22)/40)*8)-4
z=(((z-12)/12)*6)-3

if z<0:
    f=(2*z)-7
    k=0
else:
    f=0.5*z
    k=2*z

#Shape 3

def plot2(ax,transform):
    t = np.linspace(0.6, 1.8, 10024)
    data2d = np.sin(t)[:, np.newaxis] * np.cos(t)[np.newaxis, :]
    custom_cmap2 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["yellow","palegreen","palegreen","palegreen","aqua","deepskyblue"])
    rectangle = ax.imshow(data2d,cmap=custom_cmap2,
                   extent=[40, 75, 26.9, 30])

#Test

def plot1(ax,transform):
    o = np.linspace(0.6, 1.8, 10024)
    data = np.sin(o)[:, np.newaxis] * np.cos(o)[np.newaxis, :]
    custom_cmap1 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["yellow",d,"springgreen","springgreen","springgreen","springgreen","springgreen","springgreen","springgreen","springgreen",h,j,"aqua","aqua","aqua","aqua","mediumspringgreen","springgreen","palegreen","springgreen","yellow"])
    rectangle = ax.imshow(data,cmap=custom_cmap1,
                   extent=[10, 70, 40+k, 19]) #main contour 

#Shape 1:

array = (((10,20), (20,20),(26.5-f,40+k), (10,40+k)))

shape = Polygon(array, color="red")

#Shape 2:

array2 = np.array(((20,20), (22,20), (40,27), (40,30), (41,31), (41,40), (30,40)))
shape2 = Polygon(array2,facecolor="none")


#excess

array3 = np.array(((22,20),(42.5,20),(42.5,28.5+z))) #strut wedge angle triangle 
shape3 = Polygon(array3, facecolor="white")

array4 = np.array(((40-y,29.9+x+z),(41-y,31+x+z),(85,31+x+z),(85,29.9+x+z))) #smaller wedge angle (main)
shape4 = Polygon(array4, facecolor="white")


shape5 = Rectangle ((46,26+z),
                   width=29,
                   height=2.5, 
                   color="white")  #rectangle right of bleed 

shape6 = Rectangle ((0,20),
                   width=10,
                   height=25,
                   color="white") #rectangle left of inlet 

shape7 = Rectangle ((0,19),
                   width=50,
                   height=1,
                   color="white") #rectangle below geometry 

shape8 = Rectangle ((0,40+z),
                   width=85,
                   height=10,
                   color="white") #small rectangle above geometry 

array9 = np.array(((43.5,28.5+z),(49,27+z),(49,28.5+z))) #lower wedge in combustion chamber 
shape9 = Polygon(array9, facecolor="white")

array10 = np.array(((74,29.9+z),(84.5,33+z),(84.5,36+z),(74,36+z))) #outlet part 
shape10 = Polygon(array10, facecolor="white")

array11 = np.array(((86.5,27.5+z),(96,33.5+z),(96,27.5+z))) #outlet part
shape11 = Polygon(array11, facecolor="white")

array12 = np.array(((84.4,33+z),(95,33.5+z),(84.5,34.5+z))) #outlet part
shape12 = Polygon(array12, facecolor="white")

shape13 = Rectangle ((41-y,31+x+z),
                   width=45,
                   height=10,
                   color="white") #rectangle to the right of the outlet wall (main)

shape14 = Rectangle ((42,0),
                   width=33,
                   height=25.8+z,
                   color="white") #rectangle below the bleed (main)


def plot3(ax,transform):
    o = np.linspace(0.6, 1.8, 10024)
    data = np.cos(o)[:, np.newaxis] * np.sin(o)[np.newaxis, :]
    custom_cmap3 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","blue","deepskyblue","palegreen"])
    rectangle = ax.imshow(data,cmap=custom_cmap3,
                   extent=[42.5, 46, 25+z, 28.5+z]) #bleed contour 

def plot4(ax,transform):
    o = np.linspace(0.6, 1.8, 10024)
    data = np.sin(o)[:, np.newaxis] * np.cos(o)[np.newaxis, :]
    custom_cmap4 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","blue","blue","blue","blue","blue","blue","deepskyblue"])
    rectangle = ax.imshow(data,cmap=custom_cmap4,
                   extent=[75, 95, 28.5, 33.5])
    

custom_cmap2 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","blue","deepskyblue","aqua","palegreen","palegreen","yellow","yellow","lightsalmon","coral","red","Red","firebrick","firebrick"])

#Plotting shapes 

ax.add_patch(shape)
ax.add_patch(shape2) #used for reference, can be removed 
ax.add_patch(shape3)
ax.add_patch(shape4)
ax.add_patch(shape5)
ax.add_patch(shape6)
ax.add_patch(shape7)
ax.add_patch(shape8)
ax.add_patch(shape9)
#ax.add_patch(shape10)
#ax.add_patch(shape11)
#ax.add_patch(shape12)
ax.add_patch(shape13)
ax.add_patch(shape14)
plot1(ax, mtransforms.Affine2D())
#plot2(ax, mtransforms.Affine2D())
plot3(ax, mtransforms.Affine2D())
#plot4(ax, mtransforms.Affine2D())


ax, _ = mpl.colorbar.make_axes(plt.gca(),shrink=0.4)
cbar2 = mpl.colorbar.ColorbarBase(ax, cmap=custom_cmap2,
                       norm=mpl.colors.Normalize(vmin=0, vmax=2.4))



plt.show()

# %%
#major 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.patches import Rectangle
from matplotlib.patches import Polygon
import matplotlib.transforms as mtransforms
import matplotlib.colors
import matplotlib.patches as patches
from matplotlib.path import Path
import matplotlib as mpl
import math


#Axis view:

fig, ax = plt.subplots()
ax.axis([0, 85, 10, 50])

# range of x is 6.8 to 12.8 
# range of y is 41.22 to 81.22 
# range of z is 12 to 24

x=10
y=72
z=20

# r is the SBSAC
# s is the SC
# t is the SAS

r=9.3
s=1.3
t=-1.8

if t<-2.4:
    g="springgreen"
    n="aqua"
    m="deepskyblue"
elif t>-1.9:
    g="springgreen"
    n="mediumspringgreen"
    m="aqua"
else:
    g="mediumspringgreen"
    n="aqua"
    m="aqua"

if s>1.1:
    a="springgreen"
    b="springgreen"
    c="aqua"
elif s<0.85:
    a="palegreen"
    b="yellow"
    c="deepskyblue"
else:
    a="springgreen"
    b="palegreen"
    c="aqua"


if r>11:
    h="deepskyblue"
    j="deepskyblue"
    d="springgreen"
elif r<7.5:
    h="blue"
    j="blue"
    d="yellow"
else:
    h="blue"
    j="deepskyblue"
    d="springgreen"



e=60 #shock angle
angle_radians = math.radians(e)
tan = math.tan(angle_radians)
v=(20/tan)
x=(((x-6.8)/6)*2)-1 
y=(((y-41.22)/40)*8)-4
z=(((z-12)/12)*6)-3

if z<0:
    f=(2*z)-7
    k=0
else:
    f=0.5*z
    k=2*z

#Shape 3

def plot2(ax,transform):
    t = np.linspace(0.6, 1.8, 10024)
    data2d = np.sin(t)[:, np.newaxis] * np.cos(t)[np.newaxis, :]
    custom_cmap2 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["yellow","palegreen","palegreen","palegreen","aqua","deepskyblue"])
    rectangle = ax.imshow(data2d,cmap=custom_cmap2,
                   extent=[40, 75, 26.9, 30])

#Test

def plot1(ax,transform):
    o = np.linspace(0.6, 1.8, 10024)
    data = np.sin(o)[:, np.newaxis] * np.cos(o)[np.newaxis, :]
    custom_cmap1 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["yellow",b,a,d,"springgreen","springgreen","springgreen","springgreen","springgreen",c,h,j,m,"aqua","aqua",n,g,d,a,"springgreen","yellow"])
    rectangle = ax.imshow(data,cmap=custom_cmap1,
                   extent=[10, 70, 40+k, 19]) #main contour 

#Shape 1:

array = (((10,20), (20,20),(20+v,40+k), (10,40+k)))

shape = Polygon(array, color="red")

#Shape 2:

array2 = np.array(((20,20), (22,20), (40,27), (40,30), (41,31), (41,40), (30,40)))
shape2 = Polygon(array2,facecolor="none")


#excess

array3 = np.array(((22,20),(42.5,20),(42.5,28.5+z))) #strut wedge angle triangle 
shape3 = Polygon(array3, facecolor="white")

array4 = np.array(((40-y,29.9+x+z),(41-y,31+x+z),(85,31+x+z),(85,29.9+x+z))) #smaller wedge angle (main)
shape4 = Polygon(array4, facecolor="white")


shape5 = Rectangle ((46,26+z),
                   width=29,
                   height=2.5, 
                   color="white")  #rectangle right of bleed 

shape6 = Rectangle ((0,20),
                   width=10,
                   height=25,
                   color="white") #rectangle left of inlet 

shape7 = Rectangle ((0,19),
                   width=50,
                   height=1,
                   color="white") #rectangle below geometry 

shape8 = Rectangle ((0,40+z),
                   width=85,
                   height=10,
                   color="white") #small rectangle above geometry 

array9 = np.array(((43.5,28.5+z),(49,27+z),(49,28.5+z))) #lower wedge in combustion chamber 
shape9 = Polygon(array9, facecolor="white")

array10 = np.array(((74,29.9+z),(84.5,33+z),(84.5,36+z),(74,36+z))) #outlet part 
shape10 = Polygon(array10, facecolor="white")

array11 = np.array(((86.5,27.5+z),(96,33.5+z),(96,27.5+z))) #outlet part
shape11 = Polygon(array11, facecolor="white")

array12 = np.array(((84.4,33+z),(95,33.5+z),(84.5,34.5+z))) #outlet part
shape12 = Polygon(array12, facecolor="white")

shape13 = Rectangle ((41-y,31+x+z),
                   width=45,
                   height=10,
                   color="white") #rectangle to the right of the outlet wall (main)

shape14 = Rectangle ((42,0),
                   width=33,
                   height=25.8+z,
                   color="white") #rectangle below the bleed (main)


def plot3(ax,transform):
    o = np.linspace(0.6, 1.8, 10024)
    data = np.cos(o)[:, np.newaxis] * np.sin(o)[np.newaxis, :]
    custom_cmap3 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","blue","deepskyblue","palegreen"])
    rectangle = ax.imshow(data,cmap=custom_cmap3,
                   extent=[42.5, 46, 25+z, 28.5+z]) #bleed contour 

def plot4(ax,transform):
    o = np.linspace(0.6, 1.8, 10024)
    data = np.sin(o)[:, np.newaxis] * np.cos(o)[np.newaxis, :]
    custom_cmap4 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","blue","blue","blue","blue","blue","blue","deepskyblue"])
    rectangle = ax.imshow(data,cmap=custom_cmap4,
                   extent=[75, 95, 28.5, 33.5])
    

custom_cmap2 = matplotlib.colors.LinearSegmentedColormap.from_list("custom",["blue","blue","deepskyblue","aqua","palegreen","palegreen","yellow","yellow","lightsalmon","coral","red","Red","firebrick","firebrick"])

#Plotting shapes 

ax.add_patch(shape)
ax.add_patch(shape2) #used for reference, can be removed 
ax.add_patch(shape3)
ax.add_patch(shape4)
ax.add_patch(shape5)
ax.add_patch(shape6)
ax.add_patch(shape7)
ax.add_patch(shape8)
ax.add_patch(shape9)
#ax.add_patch(shape10)
#ax.add_patch(shape11)
#ax.add_patch(shape12)
ax.add_patch(shape13)
ax.add_patch(shape14)
plot1(ax, mtransforms.Affine2D())
#plot2(ax, mtransforms.Affine2D())
plot3(ax, mtransforms.Affine2D())
#plot4(ax, mtransforms.Affine2D())


ax, _ = mpl.colorbar.make_axes(plt.gca(),shrink=0.4)
cbar2 = mpl.colorbar.ColorbarBase(ax, cmap=custom_cmap2,
                       norm=mpl.colors.Normalize(vmin=0, vmax=2.4))



plt.show()
